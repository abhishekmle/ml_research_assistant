# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

import json
import joblib
import pickle

# %%
base_url = 'https://papers.nips.cc'

base_request = requests.get(base_url)

# %%
base_request.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(base_request.text, parser='html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>List of Proceedings</title>
# <link href="/static/papers/css/papers.css" rel="stylesheet"/>
# <!-- Bootstrap CSS -->
# <!-- https://codepen.io/surjithctly/pen/PJqKzQ -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
# <link href="/static/menus/css/menus.css" id="bootstrap-css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.8.1/css/all.css" integrity="sha384-50oBUHEmvpQ+1lW4y57PTFmhCaXp0ML5d60M1M7uH2+nqUivzIebhndOJK28anvf" rel="stylesheet"/>
# <script async="" src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.7/latest.js?config=TeX-MML-AM_CHTML" type="text/javascript">
# </script>
# <script type="text/x-mathjax-config">
#         MathJax.Hub.Config({
#       "tex2jax": {
#         "inlineMath": [["$","$"], ["\\(","\\)"]],
#         "displayMath": [["\\[","\\]"]],
#         "processEscapes": true
#       }
#     }
#     );
#
#     </script>
# <style>
#         @media (prefers-color-scheme: dark) {
#             body {
#                 background-color: #333;
#                 color: #eee;
#             }
#         }
#
#         .btn-spacer {
#             margin: 2px;
#         }
#
#         .footer {
#             position: fixed;
#             left: 0;
#             bottom: 0;
#             width: 100%;
#             background-color: #eee;
#             color: black;
#         }
#
#
#     </style>
# </head>
# <body>
# <nav class="navbar navbar-expand-md navbar-light bg-light">
# <button aria-controls="navbarToggler6" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarToggler6" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarToggler6">
# <a class="navbar-brand" href="/">NeurIPS Proceedings</a>
# <ul class="navbar-nav mr-auto mt-2 mt-md-0">
# <li class="nav-item">
# <a class="nav-link" href="/admin/login/?next=/admin/"><i class="fas fa-sign-in-alt" title="Login"></i></a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/admin/logout/?nextp=/admin"><i class="fas fa-sign-out-alt" title="Logout"></i></a>
# </li>
# </ul>
# <form action="/papers/search" class="form-inline my-2 my-lg-0" method="get" role="search">
# <input aria-label="Search" class="form-control mr-sm-2" id="navsearch" name="q" placeholder="Search" type="text"/>
# <button class="btn btn-outline-success my-2 my-sm-0" type="submit">Search</button>
# </form>
# </div>
# </nav>
# <br/>
# <br/>
# <div class="container-fluid">
# <div style="max-width: 600px">
# <div class="card">
# <div class="card-body">
# <h5 class="card-title">Datasets and Benchmarks</h5>
# <p class="card-text">In 2021, NeurIPS introduced a new track, Datasets and Benchmarks. The first year of that
#             track, 2021, has its own proceedings, accessible by the link below. From 2022 on, the Datasets and
#             Benchmarks papers are in the main NeurIPS proceedings.
#         </p>
# <a class="btn btn-primary" href="https://datasets-benchmarks-proceedings.neurips.cc/paper/2021">Advances in
#             Neural Information Processing Systems Datasets and Benchmarks, 2021</a>
# </div>
# </div>
# <p><br/><br/></p>
# </div>
# <div class="col-sm">
# <ul>
# <li><a href="/paper_files/paper/2023">Advances in Neural Information Processing Systems 36  (NeurIPS 2023)</a></li>
# <li><a href="/paper_files/paper/2022">Advances in Neural Information Processing Systems 35  (NeurIPS 2022)</a></li>
# <li><a href="/paper_files/paper/2021">Advances in Neural Information Processing Systems 34  (NeurIPS 2021)</a></li>
# <li><a href="/paper_files/paper/2020">Advances in Neural Information Processing Systems 33  (NeurIPS 2020)</a></li>
# <li><a href="/paper_files/paper/2019">Advances in Neural Information Processing Systems 32  (NeurIPS 2019)</a></li>
# <li><a href="/paper_files/paper/2018">Advances in Neural Information Processing Systems 31  (NeurIPS 2018)</a></li>
# <li><a href="/paper_files/paper/2017">Advances in Neural Information Processing Systems 30  (NIPS 2017)</a></li>
# <li><a href="/paper_files/paper/2016">Advances in Neural Information Processing Systems 29  (NIPS 2016)</a></li>
# <li><a href="/paper_files/paper/2015">Advances in Neural Information Processing Systems 28  (NIPS 2015)</a></li>
# <li><a href="/paper_files/paper/2014">Advances in Neural Information Processing Systems 27  (NIPS 2014)</a></li>
# <li><a href="/paper_files/paper/2013">Advances in Neural Information Processing Systems 26  (NIPS 2013)</a></li>
# <li><a href="/paper_files/paper/2012">Advances in Neural Information Processing Systems 25  (NIPS 2012)</a></li>
# <li><a href="/paper_files/paper/2011">Advances in Neural Information Processing Systems 24  (NIPS 2011)</a></li>
# <li><a href="/paper_files/paper/2010">Advances in Neural Information Processing Systems 23  (NIPS 2010)</a></li>
# <li><a href="/paper_files/paper/2009">Advances in Neural Information Processing Systems 22  (NIPS 2009)</a></li>
# <li><a href="/paper_files/paper/2008">Advances in Neural Information Processing Systems 21  (NIPS 2008)</a></li>
# <li><a href="/paper_files/paper/2007">Advances in Neural Information Processing Systems 20  (NIPS 2007)</a></li>
# <li><a href="/paper_files/paper/2006">Advances in Neural Information Processing Systems 19  (NIPS 2006)</a></li>
# <li><a href="/paper_files/paper/2005">Advances in Neural Information Processing Systems 18  (NIPS 2005)</a></li>
# <li><a href="/paper_files/paper/2004">Advances in Neural Information Processing Systems 17  (NIPS 2004)</a></li>
# <li><a href="/paper_files/paper/2003">Advances in Neural Information Processing Systems 16  (NIPS 2003)</a></li>
# <li><a href="/paper_files/paper/2002">Advances in Neural Information Processing Systems 15  (NIPS 2002)</a></li>
# <li><a href="/paper_files/paper/2001">Advances in Neural Information Processing Systems 14  (NIPS 2001)</a></li>
# <li><a href="/paper_files/paper/2000">Advances in Neural Information Processing Systems 13  (NIPS 2000)</a></li>
# <li><a href="/paper_files/paper/1999">Advances in Neural Information Processing Systems 12  (NIPS 1999)</a></li>
# <li><a href="/paper_files/paper/1998">Advances in Neural Information Processing Systems 11  (NIPS 1998)</a></li>
# <li><a href="/paper_files/paper/1997">Advances in Neural Information Processing Systems 10  (NIPS 1997)</a></li>
# <li><a href="/paper_files/paper/1996">Advances in Neural Information Processing Systems 9  (NIPS 1996)</a></li>
# <li><a href="/paper_files/paper/1995">Advances in Neural Information Processing Systems 8  (NIPS 1995)</a></li>
# <li><a href="/paper_files/paper/1994">Advances in Neural Information Processing Systems 7  (NIPS 1994)</a></li>
# <li><a href="/paper_files/paper/1993">Advances in Neural Information Processing Systems 6  (NIPS 1993)</a></li>
# <li><a href="/paper_files/paper/1992">Advances in Neural Information Processing Systems 5  (NIPS 1992)</a></li>
# <li><a href="/paper_files/paper/1991">Advances in Neural Information Processing Systems 4  (NIPS 1991)</a></li>
# <li><a href="/paper_files/paper/1990">Advances in Neural Information Processing Systems 3  (NIPS 1990)</a></li>
# <li><a href="/paper_files/paper/1989">Advances in Neural Information Processing Systems 2  (NIPS 1989)</a></li>
# <li><a href="/paper_files/paper/1988">Advances in Neural Information Processing Systems 1  (NIPS 1988)</a></li>
# <li><a href="/paper_files/paper/1987">Neural Information Processing Systems 0  (NIPS 1987)</a></li>
# </ul>
# </div>
# </div>
# <script crossorigin="anonymous" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy" src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"></script>
# <script>
#     $('.dropdown-menu a.dropdown-toggle').on('click', function (e) {
#         if (!$(this).next().hasClass('show')) {
#             $(this).parents('.dropdown-menu').first().find('.show').removeClass("show");
#         }
#         var $subMenu = $(this).next(".dropdown-menu");
#         $subMenu.toggleClass('show');
#
#
#         $(this).parents('li.nav-item.dropdown.show').on('hidden.bs.dropdown', function (e) {
#             $('.dropdown-submenu .show').removeClass("show");
#         });
#
#
#         return false;
#     });
# </script>
# <br/>
# <div class="modal fade" id="myModal">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <h4 class="modal-title">Name Change Policy</h4>
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button pull-right">×</button>
# </div>
# <div class="modal-body">
# <p>Requests for name changes in the electronic proceedings will be accepted with no questions asked.  However name changes may cause bibliographic tracking issues.  Authors are asked to consider this carefully and discuss it with their co-authors prior to requesting a name change in the electronic proceedings.</p>
# <p>Use the "Report an Issue" link to request a name change.</p>
# </div>
# <div class="modal-footer">
# </div>
# </div><!-- /.modal-content -->
# </div><!-- /.modal-dialog -->
# </div><!-- /.modal -->
# <footer class="footer">
# <div class="btn-spacer">
# <a href="https://neurips.cc/Help/Contact?select=Conference">Report an Issue</a>    |           <a class="modal-link" data-target="#myModal" data-toggle="modal" href="#">Name Change Policy</a>
# </div>
# </footer>
# <div class="hidden">Do not remove: This comment is monitored to verify that the site is working properly</div>
# <!-- Do not remove: This comment is monitored to verify that the site is working properly -->
# </body>
# </html>

# %%
year_specific_links = []

for year_link in soup.find_all('a'):
    if "paper_files" in year_link.attrs['href']:
        year_specific_links.append(f"{base_url}{year_link.attrs['href']}")

# %%
year_specific_links
# Out:
# ['https://papers.nips.cc/paper_files/paper/2023',
#  'https://papers.nips.cc/paper_files/paper/2022',
#  'https://papers.nips.cc/paper_files/paper/2021',
#  'https://papers.nips.cc/paper_files/paper/2020',
#  'https://papers.nips.cc/paper_files/paper/2019',
#  'https://papers.nips.cc/paper_files/paper/2018',
#  'https://papers.nips.cc/paper_files/paper/2017',
#  'https://papers.nips.cc/paper_files/paper/2016',
#  'https://papers.nips.cc/paper_files/paper/2015',
#  'https://papers.nips.cc/paper_files/paper/2014',
#  'https://papers.nips.cc/paper_files/paper/2013',
#  'https://papers.nips.cc/paper_files/paper/2012',
#  'https://papers.nips.cc/paper_files/paper/2011',
#  'https://papers.nips.cc/paper_files/paper/2010',
#  'https://papers.nips.cc/paper_files/paper/2009',
#  'https://papers.nips.cc/paper_files/paper/2008',
#  'https://papers.nips.cc/paper_files/paper/2007',
#  'https://papers.nips.cc/paper_files/paper/2006',
#  'https://papers.nips.cc/paper_files/paper/2005',
#  'https://papers.nips.cc/paper_files/paper/2004',
#  'https://papers.nips.cc/paper_files/paper/2003',
#  'https://papers.nips.cc/paper_files/paper/2002',
#  'https://papers.nips.cc/paper_files/paper/2001',
#  'https://papers.nips.cc/paper_files/paper/2000',
#  'https://papers.nips.cc/paper_files/paper/1999',
#  'https://papers.nips.cc/paper_files/paper/1998',
#  'https://papers.nips.cc/paper_files/paper/1997',
#  'https://papers.nips.cc/paper_files/paper/1996',
#  'https://papers.nips.cc/paper_files/paper/1995',
#  'https://papers.nips.cc/paper_files/paper/1994',
#  'https://papers.nips.cc/paper_files/paper/1993',
#  'https://papers.nips.cc/paper_files/paper/1992',
#  'https://papers.nips.cc/paper_files/paper/1991',
#  'https://papers.nips.cc/paper_files/paper/1990',
#  'https://papers.nips.cc/paper_files/paper/1989',
#  'https://papers.nips.cc/paper_files/paper/1988',
#  'https://papers.nips.cc/paper_files/paper/1987']

# %% [markdown]
# ### navigate to each year's page and get the links for all the papers of that year

# %%
all_years_soup = {}

for year_url in year_specific_links:
    year_request = requests.get(year_url)
    print(f"for year {year_url[-4:]}, status code {year_request.status_code}")
    year_soup = BeautifulSoup(year_request.text, parser='html.parser')
    all_years_soup[f"{year_url[-4:]}"] = year_soup
# Out:
# for year 2023, status code 200
# for year 2022, status code 200
# for year 2021, status code 200
# for year 2020, status code 200
# for year 2019, status code 200
# for year 2018, status code 200
# for year 2017, status code 200
# for year 2016, status code 200
# for year 2015, status code 200
# for year 2014, status code 200
# for year 2013, status code 200
# for year 2012, status code 200
# for year 2011, status code 200
# for year 2010, status code 200
# for year 2009, status code 200
# for year 2008, status code 200
# for year 2007, status code 200
# for year 2006, status code 200
# for year 2005, status code 200
# for year 2004, status code 200
# for year 2003, status code 200
# for year 2002, status code 200
# for year 2001, status code 200
# for year 2000, status code 200
# for year 1999, status code 200
# for year 1998, status code 200
# for year 1997, status code 200
# for year 1996, status code 200
# for year 1995, status code 200
# for year 1994, status code 200
# for year 1993, status code 200
# for year 1992, status code 200
# for year 1991, status code 200
# for year 1990, status code 200
# for year 1989, status code 200
# for year 1988, status code 200
# for year 1987, status code 200

# %%
all_years_soup.keys()
# Out:
# dict_keys(['2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987'])

# %%
paper_details = []
# for each year
for year in all_years_soup.keys():
    print(f"fetching for {year}")
    # for each paper in that year
    for li in all_years_soup[f"{year}"].find('ul', class_="paper-list").find_all('li'):
        paper = {}
        paper['paper_year'] = f"{year}"
        paper['paper_url'] = f"{base_url}{li.a['href']}"
        paper['paper_title'] = li.a.text
        paper['paper_author'] = li.i.text
        paper_details.append(paper)
    
df = pd.DataFrame(paper_details)
# Out:
# fetching for 2023
# fetching for 2022
# fetching for 2021
# fetching for 2020
# fetching for 2019
# fetching for 2018
# fetching for 2017
# fetching for 2016
# fetching for 2015
# fetching for 2014
# fetching for 2013
# fetching for 2012
# fetching for 2011
# fetching for 2010
# fetching for 2009
# fetching for 2008
# fetching for 2007
# fetching for 2006
# fetching for 2005
# fetching for 2004
# fetching for 2003
# fetching for 2002
# fetching for 2001
# fetching for 2000
# fetching for 1999
# fetching for 1998
# fetching for 1997
# fetching for 1996
# fetching for 1995
# fetching for 1994
# fetching for 1993
# fetching for 1992
# fetching for 1991
# fetching for 1990
# fetching for 1989
# fetching for 1988
# fetching for 1987

# %%
df
# Out:
#       paper_year                                          paper_url  \
# 0           2023  https://papers.nips.cc/paper_files/paper/2023/...
# 1           2023  https://papers.nips.cc/paper_files/paper/2023/...
# 2           2023  https://papers.nips.cc/paper_files/paper/2023/...
# 3           2023  https://papers.nips.cc/paper_files/paper/2023/...
# 4           2023  https://papers.nips.cc/paper_files/paper/2023/...
# ...          ...                                                ...
# 20281       1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20282       1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20283       1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20284       1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20285       1987  https://papers.nips.cc/paper_files/paper/1987/...
#
#                                              paper_title  \
# 0      Modelling Cellular Perturbations with the Spar...
# 1       Cross-Episodic Curriculum for Transformer Agents
# 2      PaintSeg: Painting Pixels for Training-free Se...
# 3      Bootstrapping Vision-Language Learning with De...
# 4      Path following algorithms for $\ell_2$-regular...
# ...                                                  ...
# 20281                             Connecting to the Past
# 20282  PARTITIONING OF SENSORY DATA BY A CORTICAL NET...
# 20283  A Dynamical Approach to Temporal Pattern Proce...
# 20284  Minkowski-r Back-Propagation: Learning in Conn...
# 20285  Analysis and Comparison of Different Learning ...
#
#                                             paper_author
# 0                  Michael Bereket, Theofanis Karaletsos
# 1      Lucy Xiaoyang Shi, Yunfan Jiang, Jake Grigsby,...
# 2      Xiang Li, Chung-Ching Lin, Yinpeng Chen, Ziche...
# 3            Yiren Jian, Chongyang Gao, Soroush Vosoughi
# 4                             Yunzhang Zhu, Renxiong Liu
# ...                                                  ...
# 20281                                    Bruce MacDonald
# 20282  Richard Granger, Jose Ambros-Ingerson, Howard ...
# 20283          W. Stornetta, Tad Hogg, Bernardo Huberman
# 20284                         Stephen Hanson, David Burr
# 20285                                      J. Bernasconi
#
# [20286 rows x 4 columns]

# %%
df['paper_year'].value_counts(dropna=False)
# Out:
# paper_year
# 2023    3540
# 2022    2834
# 2021    2334
# 2020    1898
# 2019    1428
# 2018    1009
# 2017     679
# 2016     569
# 2014     411
# 2015     403
# 2012     370
# 2013     360
# 2011     306
# 2010     292
# 2009     262
# 2008     250
# 2007     217
# 2004     207
# 2002     207
# 2005     207
# 2006     204
# 2003     198
# 2001     197
# 1993     158
# 1996     152
# 1995     152
# 2000     152
# 1998     151
# 1997     150
# 1999     150
# 1991     144
# 1990     143
# 1994     140
# 1992     127
# 1989     101
# 1988      94
# 1987      90
# Name: count, dtype: int64

# %%
df['paper_author'].nunique()
# Out:
# 19440

# %%
df.to_csv('paper_details_without_abstract.csv', index=False)

# %% [markdown]
# ### get the abstracts for each paper

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

import json
import joblib
import pickle

import aiohttp
import asyncio
from tqdm.asyncio import tqdm
from aiohttp import ClientSession

# %%
df = pd.read_csv('paper_details_without_abstract.csv')
print(df.shape)
df.head(2)
# Out:
# (20286, 4)
#    paper_year                                          paper_url  \
# 0        2023  https://papers.nips.cc/paper_files/paper/2023/...
# 1        2023  https://papers.nips.cc/paper_files/paper/2023/...
#
#                                          paper_title  \
# 0  Modelling Cellular Perturbations with the Spar...
# 1   Cross-Episodic Curriculum for Transformer Agents
#
#                                         paper_author
# 0              Michael Bereket, Theofanis Karaletsos
# 1  Lucy Xiaoyang Shi, Yunfan Jiang, Jake Grigsby,...

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
async def fetch_html(url: str, session: ClientSession) -> dict:
    try:
        async with session.get(url) as response:
            html = await response.text()
            return {"paper_url": url, "paper_html": html}
    except Exception as e:
        return {"paper_url": url, "paper_html": None, "error": str(e)}

async def fetch_all_html(urls: list) -> list:
    async with aiohttp.ClientSession() as session:
        tasks = []
        for url in urls:
            tasks.append(fetch_html(url, session))
        results = []
        for task in tqdm(asyncio.as_completed(tasks), total=len(tasks)):
            results.append(await task)
        return results

def scrape_urls(df: pd.DataFrame) -> pd.DataFrame:
    urls = df['paper_url'].tolist()
    loop = asyncio.get_event_loop()
    results = loop.run_until_complete(fetch_all_html(urls))
    return pd.DataFrame(results)

result_df = scrape_urls(df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 20286/20286 [02:09<00:00, 156.37it/s]

# %%
result_df.head()
# Out:
#                                            paper_url  \
# 0  https://papers.nips.cc/paper_files/paper/2014/...
# 1  https://papers.nips.cc/paper_files/paper/2014/...
# 2  https://papers.nips.cc/paper_files/paper/2022/...
# 3  https://papers.nips.cc/paper_files/paper/2022/...
# 4  https://papers.nips.cc/paper_files/paper/2014/...
#
#                                           paper_html error
# 0  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN
# 1  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN
# 2  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN
# 3  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN
# 4  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN

# %%
result_df.shape
# Out:
# (20286, 3)

# %%
result_df['error'].value_counts(dropna=False)
# Out:
# error
# NaN                    19522
# Server disconnected      764
# Name: count, dtype: int64

# %%
error_df = result_df.loc[result_df['error'].notna()].reset_index(drop=True)
error_df
# Out:
#                                              paper_url paper_html  \
# 0    https://papers.nips.cc/paper_files/paper/2019/...       None
# 1    https://papers.nips.cc/paper_files/paper/2020/...       None
# 2    https://papers.nips.cc/paper_files/paper/2022/...       None
# 3    https://papers.nips.cc/paper_files/paper/2023/...       None
# 4    https://papers.nips.cc/paper_files/paper/2023/...       None
# ..                                                 ...        ...
# 759  https://papers.nips.cc/paper_files/paper/2013/...       None
# 760  https://papers.nips.cc/paper_files/paper/2018/...       None
# 761  https://papers.nips.cc/paper_files/paper/2018/...       None
# 762  https://papers.nips.cc/paper_files/paper/2018/...       None
# 763  https://papers.nips.cc/paper_files/paper/2018/...       None
#
#                    error
# 0    Server disconnected
# 1    Server disconnected
# 2    Server disconnected
# 3    Server disconnected
# 4    Server disconnected
# ..                   ...
# 759  Server disconnected
# 760  Server disconnected
# 761  Server disconnected
# 762  Server disconnected
# 763  Server disconnected
#
# [764 rows x 3 columns]

# %%
result_df_error = scrape_urls(error_df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 764/764 [00:06<00:00, 116.86it/s]

# %%
result_df_error['error'].value_counts(dropna=False)
# Out:
# error
# NaN                    724
# Server disconnected     40
# Name: count, dtype: int64

# %%
error_df2 = result_df_error.loc[result_df_error['error'].notna()].reset_index(drop=True)
error_df2
# Out:
#                                             paper_url paper_html  \
# 0   https://papers.nips.cc/paper_files/paper/2021/...       None
# 1   https://papers.nips.cc/paper_files/paper/2019/...       None
# 2   https://papers.nips.cc/paper_files/paper/2019/...       None
# 3   https://papers.nips.cc/paper_files/paper/2019/...       None
# 4   https://papers.nips.cc/paper_files/paper/1992/...       None
# 5   https://papers.nips.cc/paper_files/paper/2020/...       None
# 6   https://papers.nips.cc/paper_files/paper/2022/...       None
# 7   https://papers.nips.cc/paper_files/paper/2022/...       None
# 8   https://papers.nips.cc/paper_files/paper/2016/...       None
# 9   https://papers.nips.cc/paper_files/paper/2022/...       None
# 10  https://papers.nips.cc/paper_files/paper/2016/...       None
# 11  https://papers.nips.cc/paper_files/paper/2021/...       None
# 12  https://papers.nips.cc/paper_files/paper/2017/...       None
# 13  https://papers.nips.cc/paper_files/paper/1996/...       None
# 14  https://papers.nips.cc/paper_files/paper/2023/...       None
# 15  https://papers.nips.cc/paper_files/paper/2007/...       None
# 16  https://papers.nips.cc/paper_files/paper/2007/...       None
# 17  https://papers.nips.cc/paper_files/paper/1992/...       None
# 18  https://papers.nips.cc/paper_files/paper/2021/...       None
# 19  https://papers.nips.cc/paper_files/paper/2003/...       None
# 20  https://papers.nips.cc/paper_files/paper/2020/...       None
# 21  https://papers.nips.cc/paper_files/paper/2022/...       None
# 22  https://papers.nips.cc/paper_files/paper/2018/...       None
# 23  https://papers.nips.cc/paper_files/paper/2020/...       None
# 24  https://papers.nips.cc/paper_files/paper/1996/...       None
# 25  https://papers.nips.cc/paper_files/paper/2023/...       None
# 26  https://papers.nips.cc/paper_files/paper/2019/...       None
# 27  https://papers.nips.cc/paper_files/paper/1999/...       None
# 28  https://papers.nips.cc/paper_files/paper/2022/...       None
# 29  https://papers.nips.cc/paper_files/paper/2023/...       None
# 30  https://papers.nips.cc/paper_files/paper/2020/...       None
# 31  https://papers.nips.cc/paper_files/paper/1999/...       None
# 32  https://papers.nips.cc/paper_files/paper/2023/...       None
# 33  https://papers.nips.cc/paper_files/paper/1990/...       None
# 34  https://papers.nips.cc/paper_files/paper/2018/...       None
# 35  https://papers.nips.cc/paper_files/paper/2023/...       None
# 36  https://papers.nips.cc/paper_files/paper/2020/...       None
# 37  https://papers.nips.cc/paper_files/paper/2018/...       None
# 38  https://papers.nips.cc/paper_files/paper/2019/...       None
# 39  https://papers.nips.cc/paper_files/paper/2021/...       None
#
#                   error
# 0   Server disconnected
# 1   Server disconnected
# 2   Server disconnected
# 3   Server disconnected
# 4   Server disconnected
# 5   Server disconnected
# 6   Server disconnected
# 7   Server disconnected
# 8   Server disconnected
# 9   Server disconnected
# 10  Server disconnected
# 11  Server disconnected
# 12  Server disconnected
# 13  Server disconnected
# 14  Server disconnected
# 15  Server disconnected
# 16  Server disconnected
# 17  Server disconnected
# 18  Server disconnected
# 19  Server disconnected
# 20  Server disconnected
# 21  Server disconnected
# 22  Server disconnected
# 23  Server disconnected
# 24  Server disconnected
# 25  Server disconnected
# 26  Server disconnected
# 27  Server disconnected
# 28  Server disconnected
# 29  Server disconnected
# 30  Server disconnected
# 31  Server disconnected
# 32  Server disconnected
# 33  Server disconnected
# 34  Server disconnected
# 35  Server disconnected
# 36  Server disconnected
# 37  Server disconnected
# 38  Server disconnected
# 39  Server disconnected

# %%
result_df_error2 = scrape_urls(error_df2)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 40/40 [00:01<00:00, 24.74it/s]

# %%
result_df_error2
# Out:
#                                             paper_url  \
# 0   https://papers.nips.cc/paper_files/paper/2007/...
# 1   https://papers.nips.cc/paper_files/paper/1999/...
# 2   https://papers.nips.cc/paper_files/paper/2007/...
# 3   https://papers.nips.cc/paper_files/paper/2023/...
# 4   https://papers.nips.cc/paper_files/paper/1992/...
# 5   https://papers.nips.cc/paper_files/paper/2023/...
# 6   https://papers.nips.cc/paper_files/paper/2021/...
# 7   https://papers.nips.cc/paper_files/paper/2019/...
# 8   https://papers.nips.cc/paper_files/paper/2023/...
# 9   https://papers.nips.cc/paper_files/paper/2022/...
# 10  https://papers.nips.cc/paper_files/paper/2017/...
# 11  https://papers.nips.cc/paper_files/paper/2020/...
# 12  https://papers.nips.cc/paper_files/paper/1996/...
# 13  https://papers.nips.cc/paper_files/paper/1999/...
# 14  https://papers.nips.cc/paper_files/paper/2021/...
# 15  https://papers.nips.cc/paper_files/paper/2019/...
# 16  https://papers.nips.cc/paper_files/paper/2020/...
# 17  https://papers.nips.cc/paper_files/paper/1990/...
# 18  https://papers.nips.cc/paper_files/paper/2021/...
# 19  https://papers.nips.cc/paper_files/paper/2019/...
# 20  https://papers.nips.cc/paper_files/paper/2022/...
# 21  https://papers.nips.cc/paper_files/paper/2023/...
# 22  https://papers.nips.cc/paper_files/paper/2003/...
# 23  https://papers.nips.cc/paper_files/paper/2018/...
# 24  https://papers.nips.cc/paper_files/paper/2023/...
# 25  https://papers.nips.cc/paper_files/paper/1996/...
# 26  https://papers.nips.cc/paper_files/paper/2019/...
# 27  https://papers.nips.cc/paper_files/paper/1992/...
# 28  https://papers.nips.cc/paper_files/paper/2018/...
# 29  https://papers.nips.cc/paper_files/paper/2018/...
# 30  https://papers.nips.cc/paper_files/paper/2021/...
# 31  https://papers.nips.cc/paper_files/paper/2019/...
# 32  https://papers.nips.cc/paper_files/paper/2016/...
# 33  https://papers.nips.cc/paper_files/paper/2016/...
# 34  https://papers.nips.cc/paper_files/paper/2022/...
# 35  https://papers.nips.cc/paper_files/paper/2022/...
# 36  https://papers.nips.cc/paper_files/paper/2020/...
# 37  https://papers.nips.cc/paper_files/paper/2022/...
# 38  https://papers.nips.cc/paper_files/paper/2020/...
# 39  https://papers.nips.cc/paper_files/paper/2020/...
#
#                                            paper_html
# 0   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 1   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 2   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 3   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 4   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 5   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 6   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 7   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 8   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 9   \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 10  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 11  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 12  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 13  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 14  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 15  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 16  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 17  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 18  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 19  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 20  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 21  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 22  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 23  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 24  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 25  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 26  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 27  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 28  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 29  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 30  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 31  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 32  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 33  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 34  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 35  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 36  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 37  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 38  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 39  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...

# %%
final_html_df = pd.concat([result_df_error2, result_df_error, result_df], ignore_index=True).drop_duplicates(subset=['paper_url'], keep='first')
print(final_html_df.shape)
# Out:
# (20286, 3)

# %%
df.shape
# Out:
# (20286, 4)

# %%
final_html_df.head(3)
# Out:
#                                            paper_url  \
# 0  https://papers.nips.cc/paper_files/paper/2007/...
# 1  https://papers.nips.cc/paper_files/paper/1999/...
# 2  https://papers.nips.cc/paper_files/paper/2007/...
#
#                                           paper_html error
# 0  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN
# 1  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN
# 2  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...   NaN

# %%
final_html_df['error'].value_counts(dropna=False)
# Out:
# error
# NaN    20286
# Name: count, dtype: int64

# %%
html_df = final_html_df.drop('error', axis=1)
html_df.head(3)
# Out:
#                                            paper_url  \
# 0  https://papers.nips.cc/paper_files/paper/2007/...
# 1  https://papers.nips.cc/paper_files/paper/1999/...
# 2  https://papers.nips.cc/paper_files/paper/2007/...
#
#                                           paper_html
# 0  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 1  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 2  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...

# %%
html_df.shape
# Out:
# (20286, 2)

# %%
final_df = df.merge(html_df, on='paper_url', how='inner')
print(final_df.shape)
# Out:
# (20286, 5)

# %%
final_df.head(3)
# Out:
#    paper_year                                          paper_url  \
# 0        2023  https://papers.nips.cc/paper_files/paper/2023/...
# 1        2023  https://papers.nips.cc/paper_files/paper/2023/...
# 2        2023  https://papers.nips.cc/paper_files/paper/2023/...
#
#                                          paper_title  \
# 0  Modelling Cellular Perturbations with the Spar...
# 1   Cross-Episodic Curriculum for Transformer Agents
# 2  PaintSeg: Painting Pixels for Training-free Se...
#
#                                         paper_author  \
# 0              Michael Bereket, Theofanis Karaletsos
# 1  Lucy Xiaoyang Shi, Yunfan Jiang, Jake Grigsby,...
# 2  Xiang Li, Chung-Ching Lin, Yinpeng Chen, Ziche...
#
#                                           paper_html
# 0  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 1  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 2  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...

# %%
final_df.to_csv('paper_details_with_html.csv', index=False)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20286 entries, 0 to 20285
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   paper_year    20286 non-null  int64
#  1   paper_url     20286 non-null  object
#  2   paper_title   20286 non-null  object
#  3   paper_author  20282 non-null  object
#  4   paper_html    20286 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 792.5+ KB

# %% [markdown]
# ### fetch cleaned abstract

# %%
final_df = pd.read_csv('paper_details_with_html.csv')
final_df.shape
# Out:
# (20286, 5)

# %%
final_df.head(1)
# Out:
#    paper_year                                          paper_url  \
# 0        2023  https://papers.nips.cc/paper_files/paper/2023/...
#
#                                          paper_title  \
# 0  Modelling Cellular Perturbations with the Spar...
#
#                             paper_author  \
# 0  Michael Bereket, Theofanis Karaletsos
#
#                                           paper_html
# 0  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...

# %%
#t = BeautifulSoup(final_df.loc[0, 'paper_html'], parser='html.parser')

# %%
#t.find('h4', string='Abstract')

# %%
#t.find_all('script')[1]

# %%
#t

# %%
def get_abstract(text):
    try:
        paper_soup = BeautifulSoup(text, parser='html.parser')
        start_tag = paper_soup.find('h4', string='Abstract')
        end_tag = paper_soup.find_all('script')[1]
        concatenated_text = ""
        # Find all the tags between the start and end tags
        for tag in start_tag.find_next_siblings():
            if tag == end_tag:
                break
            if tag.name == 'p' or tag.name=='pre':  # Only concatenate the text of <p> tags
                concatenated_text += tag.get_text()
    except:
        concatenated_text = np.nan
    return concatenated_text

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
x = final_df['paper_html'].progress_apply(get_abstract)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20286/20286 [00:48<00:00, 418.50it/s]

# %%
final_df['paper_abstract'] = x.copy()

# %%
final_df['paper_abstract'].value_counts(dropna=False)
# Out:
# paper_abstract
# Abstract Unavailable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          55
# We show how an "Elman" network architecture, constructed from  recurrently connected oscillatory associative memory network mod(cid:173) ules, can employ selective "attentional" control of synchronization  to direct the flow of communication and computation within the  architecture to solve a grammatical inference problem.  Previously we have shown how the discrete time "Elman" network  algorithm can be implemented in a network completely described  by continuous ordinary differential equations. The time steps (ma(cid:173) chine cycles) of the system are implemented by rhythmic variation  (clocking) of a bifurcation parameter. In this architecture, oscilla(cid:173) tion amplitude codes the information content or activity of a mod(cid:173) ule (unit), whereas phase and frequency are used to "softwire" the  network. Only synchronized modules communicate by exchang(cid:173) ing amplitude information; the activity of non-resonating modules  contributes incoherent crosstalk noise.  Attentional control is modeled as a special subset of the hidden  modules with ouputs which affect the resonant frequencies of other  hidden modules. They control synchrony among the other mod(cid:173) ules and direct the flow of computation (attention) to effect transi(cid:173) tions between two subgraphs of a thirteen state automaton which  the system emulates to generate a Reber grammar. The internal  crosstalk noise is used to drive the required random transitions of  the automaton.                                    2
# We  study  the  dynamics  of supervised  learning  in  layered  neural  net(cid:173) works,  in  the regime where the size p of the training set is  proportional  to the number N  of inputs.  Here the local fields  are no longer described  by  Gaussian  distributions.  We  use  dynamical  replica theory  to  predict  the  evolution  of macroscopic  observables,  including  the  relevant  error  measures, incorporating the old formalism  in the limit piN --t  00.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             2
# We  propose a new in-sample cross validation based method (randomized  GACV) for choosing smoothing or bandwidth parameters that govern the  bias-variance or fit-complexity tradeoff in  'soft' classification.  Soft clas(cid:173) sification refers to  a  learning procedure which  estimates the probability  that an example with a given attribute vector is  in  class  1 vs  class O.  The  target  for  optimizing  the  the  tradeoff is  the  Kullback-Liebler distance  between  the  estimated  probability  distribution  and  the  'true'  probabil(cid:173) ity  distribution,  representing  knowledge of an  infinite  population.  The  method uses a randomized estimate of the trace of a Hessian and mimics  cross validation at the cost of a single relearning with perturbed outcome  data.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2
# We provide a model of the standard watermaze task, and of a more  challenging task involving novel platform locations, in which rats  exhibit one-trial learning after a few days of training.  The model  uses hippocampal place cells to support reinforcement learning,  and also,  in an integrated manner,  to build  and use  allocentric  coordinates.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ..
# Learned representations in deep reinforcement learning (DRL) have to extract task-relevant information from complex observations, balancing between robustness to distraction and informativeness to the policy. Such stable and rich representations, often learned via modern function approximation techniques, can enable practical application of the policy improvement theorem, even in high-dimensional continuous state-action spaces. Bisimulation metrics offer one solution to this representation learning problem, by collapsing functionally similar states together in representation space, which promotes invariance to noise and distractors. In this work, we generalize value function approximation bounds for on-policy bisimulation metrics to non-optimal policies and approximate environment dynamics. Our theoretical results help us identify embedding pathologies that may occur in practical use. In particular, we find that these issues stem from an underconstrained dynamics model and an unstable dependence of the embedding norm on the reward signal in environments with sparse rewards. Further, we propose a set of practical remedies: (i) a norm constraint on the representation space, and (ii) an extension of prior approaches with intrinsic rewards and latent space regularization. Finally, we provide evidence that the resulting method is not only more robust to sparse reward functions, but also able to solve challenging continuous control tasks with observational distractions, where prior methods fail.     1
# Most of the existing GNNs can be modeled via the Uniform Message Passing framework. This framework considers all the attributes of each node in its entirety, shares the uniform propagation weights along each edge,  and focuses on the uniform weight learning. The design of this framework possesses two prerequisites, the simplification of homophily and heterophily to the node-level property and the ignorance of attribute differences. Unfortunately, different attributes possess diverse characteristics. In this paper, the network homophily rate defined with  respect to the node labels is extended to attribute homophily rate by taking the attributes as weak labels. Based on this attribute homophily rate, we propose a Diverse Message Passing (DMP) framework, which specifies every attribute propagation weight on each edge. Besides, we propose two specific strategies to significantly reduce the computational complexity of DMP to prevent the overfitting issue.  By investigating the spectral characteristics, existing spectral GNNs are actually equivalent to a degenerated version of DMP.  From the perspective of numerical optimization, we provide a theoretical analysis to demonstrate DMP's powerful representation ability and the ability of alleviating the over-smoothing issue.  Evaluations on various  real networks demonstrate the superiority of our DMP on  handling the networks with heterophily  and alleviating the over-smoothing issue, compared to the existing state-of-the-arts.                         1
# Understanding the operation of biological and artificial networks remains a difficult and important challenge. To identify general principles, researchers are increasingly interested in surveying large collections of networks that are trained on, or biologically adapted to, similar tasks. A standardized set of analysis tools is now needed to identify how network-level covariates---such as architecture, anatomical brain region, and model organism---impact neural representations (hidden layer activations). Here, we provide a rigorous foundation for these analyses by defining a broad family of metric spaces that quantify representational dissimilarity. Using this framework, we modify existing representational similarity measures based on canonical correlation analysis and centered kernel alignment to satisfy the triangle inequality, formulate a novel metric that respects the inductive biases in convolutional layers, and identify approximate Euclidean embeddings that enable network representations to be incorporated into essentially any off-the-shelf machine learning method. We demonstrate these methods on large-scale datasets from biology (Allen Institute Brain Observatory) and deep learning (NAS-Bench-101). In doing so, we identify relationships between neural representations that are interpretable in terms of anatomical features and model performance.                                                                                                                                                   1
# Traditional methods for kernel selection rely on parametric kernel functions or a combination thereof and although the kernel hyperparameters are tuned, these methods often provide sub-optimal results due to the limitations induced by the parametric forms. In this paper, we propose a novel formulation for kernel selection using efficient Bayesian optimisation to find the best fitting non-parametric kernel. The kernel is expressed using a linear combination of functions sampled from a prior Gaussian Process (GP) defined by a hyperkernel. We also provide a mechanism to ensure the positive definiteness of the Gram matrix constructed using the resultant kernels. Our experimental results on GP regression and Support Vector Machine (SVM) classification tasks involving both synthetic functions and several real-world datasets show the superiority of our approach over the state-of-the-art.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# We investigate the behavior of different learning algorithms for networks of neuron-like units. As test cases we use simple pat(cid:173) tern association problems, such as the XOR-problem and symmetry de(cid:173) tection problems. The algorithms considered are either versions of  the Boltzmann machine learning rule or based on the backpropagation  of errors. We also propose and analyze a generalized delta rule for  linear threshold units. We  find that the performance of a given  learning algorithm depends strongly on the type of units used. In  particular, we observe that networks with ±1 units quite generally  exhibit a significantly better learning behavior than the correspon(cid:173) ding 0,1 versions. We also demonstrate that an adaption of the  weight-structure to  the symmetries of the problem can lead to a  drastic increase in learning speed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Name: count, Length: 20214, dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20286 entries, 0 to 20285
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   paper_year      20286 non-null  int64
#  1   paper_url       20286 non-null  object
#  2   paper_title     20286 non-null  object
#  3   paper_author    20282 non-null  object
#  4   paper_html      20286 non-null  object
#  5   paper_abstract  20286 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 951.0+ KB

# %%
final_df.head(2)
# Out:
#    paper_year                                          paper_url  \
# 0        2023  https://papers.nips.cc/paper_files/paper/2023/...
# 1        2023  https://papers.nips.cc/paper_files/paper/2023/...
#
#                                          paper_title  \
# 0  Modelling Cellular Perturbations with the Spar...
# 1   Cross-Episodic Curriculum for Transformer Agents
#
#                                         paper_author  \
# 0              Michael Bereket, Theofanis Karaletsos
# 1  Lucy Xiaoyang Shi, Yunfan Jiang, Jake Grigsby,...
#
#                                           paper_html  \
# 0  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
# 1  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
#
#                                       paper_abstract
# 0  Generative models of observations under interv...
# 1  We present a new algorithm, Cross-Episodic Cur...

# %%
# final_df.to_csv('papers_with_abstract.csv', index=False)
final_df[['paper_year', 'paper_url', 'paper_title', 'paper_author', 'paper_abstract']].to_parquet('ml_research_assistant/data/papers_with_abstract.parquet', index=False)

# %%
final_df.sample(1)
# Out:
#       paper_year                                          paper_url  \
# 9028        2020  https://papers.nips.cc/paper_files/paper/2020/...
#
#                                             paper_title   paper_author  \
# 9028  On the Tightness of Semidefinite Relaxations f...  Richard Zhang
#
#                                              paper_html  \
# 9028  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...
#
#                                          paper_abstract
# 9028  The robustness of a neural network to adversar...

# %%
final_df.loc[6276, 'paper_url']
# Out:
# 'https://papers.nips.cc/paper_files/paper/2022/hash/f649556471416b35e60ae0de7c1e3619-Abstract-Conference.html'

# %%
final_df.loc[6276, 'paper_abstract']
# Out:
# 'Recent progress in reinforcement learning (RL) has started producing generally capable agents that can solve a distribution of complex environments. These agents are typically tested on fixed, human-authored environments. On the other hand, quality diversity (QD) optimization has been proven to be an effective component of environment generation algorithms, which can generate collections of high-quality environments that are diverse in the resulting agent behaviors. However, these algorithms require potentially expensive simulations of agents on newly generated environments. We propose Deep Surrogate Assisted Generation of Environments (DSAGE), a sample-efficient QD environment generation algorithm that maintains a deep surrogate model for predicting agent behaviors in new environments. Results in two benchmark domains show that DSAGE significantly outperforms existing QD environment generation algorithms in discovering collections of environments that elicit diverse behaviors of a state-of-the-art RL agent and a planning agent. Our source code and videos are available at https://dsagepaper.github.io/.'

# %%
final_df.loc[final_df['paper_abstract']==""]
# Out:
# Empty DataFrame
# Columns: [paper_year, paper_url, paper_title, paper_author, paper_html, paper_abstract]
# Index: []

# %%
for x in final_df.loc[final_df['paper_abstract']=="", 'paper_url']:
    print(x)

# %%
final_df.loc[final_df['paper_abstract']=="Abstract Unavailable"]
# Out:
#        paper_year                                          paper_url  \
# 15495        2012  https://papers.nips.cc/paper_files/paper/2012/...
# 15700        2012  https://papers.nips.cc/paper_files/paper/2012/...
# 15800        2012  https://papers.nips.cc/paper_files/paper/2012/...
# 17268        2006  https://papers.nips.cc/paper_files/paper/2006/...
# 17357        2006  https://papers.nips.cc/paper_files/paper/2006/...
# 17850        2003  https://papers.nips.cc/paper_files/paper/2003/...
# 18073        2002  https://papers.nips.cc/paper_files/paper/2002/...
# 18075        2002  https://papers.nips.cc/paper_files/paper/2002/...
# 18244        2001  https://papers.nips.cc/paper_files/paper/2001/...
# 18322        2001  https://papers.nips.cc/paper_files/paper/2001/...
# 18404        2000  https://papers.nips.cc/paper_files/paper/2000/...
# 18775        1998  https://papers.nips.cc/paper_files/paper/1998/...
# 19167        1995  https://papers.nips.cc/paper_files/paper/1995/...
# 19190        1995  https://papers.nips.cc/paper_files/paper/1995/...
# 19221        1995  https://papers.nips.cc/paper_files/paper/1995/...
# 19269        1995  https://papers.nips.cc/paper_files/paper/1995/...
# 19271        1995  https://papers.nips.cc/paper_files/paper/1995/...
# 19364        1994  https://papers.nips.cc/paper_files/paper/1994/...
# 19424        1994  https://papers.nips.cc/paper_files/paper/1994/...
# 19431        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19444        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19446        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19450        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19490        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19493        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19494        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19523        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19542        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19550        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19562        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19568        1993  https://papers.nips.cc/paper_files/paper/1993/...
# 19660        1992  https://papers.nips.cc/paper_files/paper/1992/...
# 19730        1991  https://papers.nips.cc/paper_files/paper/1991/...
# 19932        1990  https://papers.nips.cc/paper_files/paper/1990/...
# 20036        1989  https://papers.nips.cc/paper_files/paper/1989/...
# 20075        1989  https://papers.nips.cc/paper_files/paper/1989/...
# 20084        1989  https://papers.nips.cc/paper_files/paper/1989/...
# 20107        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20113        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20114        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20119        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20134        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20148        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20149        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20165        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20176        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20182        1988  https://papers.nips.cc/paper_files/paper/1988/...
# 20211        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20213        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20216        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20239        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20245        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20266        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20280        1987  https://papers.nips.cc/paper_files/paper/1987/...
# 20282        1987  https://papers.nips.cc/paper_files/paper/1987/...
#
#                                              paper_title  \
# 15495  A dynamic excitatory-inhibitory network in a V...
# 15700  An Integer Optimization Approach to Associativ...
# 15800          Online Sum-Product Computation Over Trees
# 17268        Learning to be Bayesian without Supervision
# 17357         TrueSkill™: A Bayesian Skill Rating System
# 17850   Local Phase Coherence and the Perception of Blur
# 18073                                PAC-Bayes & Margins
# 18075  Maximally Informative Dimensions: Analyzing Ne...
# 18244  Learning Spike-Based Correlations and Conditio...
# 18322         Perceptual Metamers in Stereoscopic Vision
# 18404  Using the Nyström Method to Speed Up Kernel Ma...
# 18775  Efficient Bayesian Parameter Estimation in Lar...
# 19167  Pruning with generalization based weight salie...
# 19190  High-Performance Job-Shop Scheduling With A Ti...
# 19221     Absence of Cycles in Symmetric Neural Networks
# 19269  A Bound on the Error of Cross Validation Using...
# 19271  Strong Unimodality and Exact Learning of Const...
# 19364  Direct Multi-Step Time Series Prediction Using...
# 19424  H∞ Optimal Training Algorithms and their Relat...
# 19431  Putting It All Together: Methods for Combining...
# 19444  Robot Learning: Exploration and Continuous Dom...
# 19446  Catastrophic interference in connectionist net...
# 19450  Processing of Visual and Auditory Space and It...
# 19490  What Does the Hippocampus Compute?: A Precis o...
# 19493  Memory-Based Methods for Regression and Classi...
# 19494   Neural Network Methods for Optimization Problems
# 19523  Generation of Internal Representation by α-Tra...
# 19542  Learning in Computer Vision and Image Understa...
# 19550  Neurobiology, Psychophysics, and Computational...
# 19562  Functional Models of Selective Attention and C...
# 19568  Complexity Issues in Neural Computation and Le...
# 19660  On Learning µ-Perceptron Networks with Binary ...
# 19730  Analog LSI Implementation of an Auto-Adaptive ...
# 19932  A Neural Network Approach for Three-Dimensiona...
# 20036  Digital-Analog Hybrid Synapse Chips for Electr...
# 20075  Subgrouping Reduces Complexity and Speeds Up L...
# 20084  On the Distribution of the Number of Local Min...
# 20107          Computer Modeling of Associative Learning
# 20113     Performance of a Stochastic Learning Microchip
# 20114                             Song Learning in Birds
# 20119         Linear Learning: Landscapes and Algorithms
# 20134                                Neural Architecture
# 20148  A Connectionist Expert System that Actually Works
# 20149                             Cricket Wind Detection
# 20165                     A Self-Learning Neural Network
# 20176  Speech Recognition: Statistical and Neural Inf...
# 20182  A Model of Neural Oscillator for a Unified Sub...
# 20211  Ensemble' Boltzmann Units have Collective Comp...
# 20213  Neuromorphic Networks Based on Sparse Optical ...
# 20216  A Computer Simulation of Cerebral Neocortex: C...
# 20239          Computing Motion Using Resistive Networks
# 20245  Teaching Artificial Neural Systems to Drive: M...
# 20266     The Sigmoid Nonlinearity in Prepyriform Cortex
# 20280  Stochastic Learning Networks and their Electro...
# 20282  PARTITIONING OF SENSORY DATA BY A CORTICAL NET...
#
#                                             paper_author  \
# 15495                                           Juan Huo
# 15700   Dimitris Bertsimas, Allison Chang, Cynthia Rudin
# 15800      Mark Herbster, Stephen Pasteris, Fabio Vitale
# 17268                     Martin Raphan, Eero Simoncelli
# 17357            Ralf Herbrich, Tom Minka, Thore Graepel
# 17850                         Zhou Wang, Eero Simoncelli
# 18073                   John Langford, John Shawe-Taylor
# 18075       Tatyana Sharpee, Nicole Rust, William Bialek
# 18244                Aaron Shon, David Hsu, Chris Diorio
# 18322                                          B. Backus
# 18404              Christopher Williams, Matthias Seeger
# 18775                         Nir Friedman, Yoram Singer
# 19167           Morten Pedersen, Lars Hansen, Jan Larsen
# 19190                       Wei Zhang, Thomas Dietterich
# 19221  Xin Wang, Arun Jagota, Fernanda Botelho, Max G...
# 19269                                     Michael Kearns
# 19271                 Mario Marchand, Saeed Hadjifaradji
# 19364                   Peter T. Kazlas, Andreas Weigend
# 19424                      Babak Hassibi, Thomas Kailath
# 19431                                    Michael Perrone
# 19444                                         David Cohn
# 19446                                      Robert French
# 19450           Josef Rauschecker, Terrence J. Sejnowski
# 19490                                         Mark Gluck
# 19493  Thomas Dietterich, Dietrich Wettschereck, Chri...
# 19494                                        Arun Jagota
# 19523                                   Ryotaro Kamimura
# 19542                                    Hayit Greenspan
# 19550                      Ernst Niebur, Bruno Olshausen
# 19562                                 Thomas Hildebrandt
# 19568                      V. P. Roychowdhury, K.-Y. Siu
# 19660      Mostefa Golea, Mario Marchand, Thomas Hancock
# 19730    Marc Cohen, Philippe Pouliquen, Andreas Andreou
# 19932                                       Volker Tresp
# 20036            Alexander Moopenn, T. Duong, A. Thakoor
# 20075                                       David Zipser
# 20084          Pierre Baldi, Yosef Rinott, Charles Stein
# 20107            Daniel Alkon, Francis Quek, Thomas Vogl
# 20113       Joshua Alspector, Bhusan Gupta, Robert Allen
# 20114                                         M. Konishi
# 20119                                       Pierre Baldi
# 20134                              Valentino Braitenberg
# 20148         Richard Fozzard, Gary Bradshaw, Louis Ceci
# 20149                                        John Miller
# 20165                           Allan Hartstein, R. Koch
# 20176                                        John Bridle
# 20182  Alexandr Kirillov, G. N. Borisyuk, R. M. Boris...
# 20211                       Mark Derthick, Joe Tebelskis
# 20213                         Mario Vecchi, Jawad Salehi
# 20216                    Alexander Singer, John Donoghue
# 20239  Christof Koch, Jin Luo, Carver Mead, James Hut...
# 20245                        J. F. Shepanski, S. A. Macy
# 20266                                      Frank Eeckman
# 20280  Joshua Alspector, Robert Allen, Victor Hu, Sri...
# 20282  Richard Granger, Jose Ambros-Ingerson, Howard ...
#
#                                               paper_html        paper_abstract
# 15495  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 15700  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 15800  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 17268  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 17357  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 17850  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 18073  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 18075  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 18244  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 18322  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 18404  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 18775  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19167  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19190  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19221  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19269  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19271  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19364  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19424  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19431  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19444  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19446  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19450  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19490  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19493  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19494  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19523  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19542  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19550  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19562  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19568  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19660  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19730  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 19932  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20036  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20075  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20084  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20107  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20113  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20114  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20119  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20134  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20148  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20149  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20165  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20176  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20182  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20211  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20213  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20216  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20239  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20245  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20266  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20280  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable
# 20282  \n\n\n\n<!doctype html>\n<html lang="en">\n<he...  Abstract Unavailable

# %%
for x in final_df.loc[final_df['paper_abstract']=="Abstract Unavailable", 'paper_url']:
    print(x)
# Out:
# https://papers.nips.cc/paper_files/paper/2012/hash/12780ea688a71dabc284b064add459a4-Abstract.html
# https://papers.nips.cc/paper_files/paper/2012/hash/9e7ba617ad9e69b39bd0c29335b79629-Abstract.html
# https://papers.nips.cc/paper_files/paper/2012/hash/e2c4a40d50b47094f571e40efead3900-Abstract.html
# https://papers.nips.cc/paper_files/paper/2006/hash/908c9a564a86426585b29f5335b619bc-Abstract.html
# https://papers.nips.cc/paper_files/paper/2006/hash/f44ee263952e65b3610b8ba51229d1f9-Abstract.html
# https://papers.nips.cc/paper_files/paper/2003/hash/565030e1fce4e481f9823a7de3b8a047-Abstract.html
# https://papers.nips.cc/paper_files/paper/2002/hash/68d309812548887400e375eaa036d2f1-Abstract.html
# https://papers.nips.cc/paper_files/paper/2002/hash/69dafe8b58066478aea48f3d0f384820-Abstract.html
# https://papers.nips.cc/paper_files/paper/2001/hash/4afd521d77158e02aed37e2274b90c9c-Abstract.html
# https://papers.nips.cc/paper_files/paper/2001/hash/b5f1e8fb36cd7fbeb7988e8639ac79e9-Abstract.html
# https://papers.nips.cc/paper_files/paper/2000/hash/19de10adbaa1b2ee13f77f679fa1483a-Abstract.html
# https://papers.nips.cc/paper_files/paper/1998/hash/962e56a8a0b0420d87272a682bfd1e53-Abstract.html
# https://papers.nips.cc/paper_files/paper/1995/hash/3473decccb0509fb264818a7512a8b9b-Abstract.html
# https://papers.nips.cc/paper_files/paper/1995/hash/4f16c818875d9fcb6867c7bdc89be7eb-Abstract.html
# https://papers.nips.cc/paper_files/paper/1995/hash/8b4066554730ddfaa0266346bdc1b202-Abstract.html
# https://papers.nips.cc/paper_files/paper/1995/hash/dc58e3a306451c9d670adcd37004f48f-Abstract.html
# https://papers.nips.cc/paper_files/paper/1995/hash/df0aab058ce179e4f7ab135ed4e641a9-Abstract.html
# https://papers.nips.cc/paper_files/paper/1994/hash/8d6dc35e506fc23349dd10ee68dabb64-Abstract.html
# https://papers.nips.cc/paper_files/paper/1994/hash/f57a2f557b098c43f11ab969efe1504b-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/0537fb40a68c18da59a35c2bfe1ca554-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/22fb0cee7e1f3bde58293de743871417-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/28267ab848bcf807b2ed53c3a8f8fc8a-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/2ca65f58e35d9ad45bf7f3ae5cfd08f1-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/6c29793a140a811d0c45ce03c1c93a28-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/6e7b33fdea3adc80ebd648fffb665bb8-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/6f2268bd1d3d3ebaabb04d6b5d099425-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/98d6f58ab0dafbb86b083a001561bb34-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/beb22fb694d513edcf5533cf006dfeae-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/ce78d1da254c0843eb23951ae077ff5f-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/e0cf1f47118daebc5b16269099ad7347-Abstract.html
# https://papers.nips.cc/paper_files/paper/1993/hash/e97ee2054defb209c35fe4dc94599061-Abstract.html
# https://papers.nips.cc/paper_files/paper/1992/hash/8c7bbbba95c1025975e548cee86dfadc-Abstract.html
# https://papers.nips.cc/paper_files/paper/1991/hash/1bb91f73e9d31ea2830a5e73ce3ed328-Abstract.html
# https://papers.nips.cc/paper_files/paper/1990/hash/8bf1211fd4b7b94528899de0a43b9fb3-Abstract.html
# https://papers.nips.cc/paper_files/paper/1989/hash/555d6702c950ecb729a966504af0a635-Abstract.html
# https://papers.nips.cc/paper_files/paper/1989/hash/c24cd76e1ce41366a4bbe8a49b02a028-Abstract.html
# https://papers.nips.cc/paper_files/paper/1989/hash/d947bf06a885db0d477d707121934ff8-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/069059b7ef840f0c74a814ec9237b6ec-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/140f6969d5213fd0ece03148e62e461e-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/149e9677a5989fd342ae44213df68868-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/202cb962ac59075b964b07152d234b70-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/5878a7ab84fb43402106c575658472fa-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/7f1de29e6da19d22b51c68001e7e0e54-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/7f6ffaa6bb0b408017b62254211691b5-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/a2557a7b2e94197ff767970b67041697-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/bf8229696f7a3bb4700cfddef19fa23f-Abstract.html
# https://papers.nips.cc/paper_files/paper/1988/hash/da4fb5c6e93e74d3df8527599fa62642-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/32bb90e8976aab5298d5da10fe66f21d-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/3416a75f4cea9109507cacd8e2f2aefc-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/37693cfc748049e45d87b8c7d8b9aacd-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/8e296a067a37563370ded05f5a3bf3ec-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/9a1158154dfa42caddbd0694a4e9bdc8-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/c9f0f895fb98ab9159f51fd0297e236d-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/f033ab37c30201f73f142449d037028d-Abstract.html
# https://papers.nips.cc/paper_files/paper/1987/hash/f7177163c833dff4b38fc8d2872f1ec6-Abstract.html
